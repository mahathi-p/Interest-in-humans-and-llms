# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
import regex as re

# %%
old_gispy = "/Users/mahathi/Interest-in-humans-and-llms/data/complete_gispy_scores.csv"
all_texts = pd.read_csv(old_gispy)
all_texts = all_texts[['conversation_id', 'id', 'd_id', 'text']]
all_texts
# Out:
#       conversation_id     id           d_id
# 0                   7  45939  007_45939.txt  \
# 1                   7  45940  007_45940.txt
# 2                   7  45941  007_45941.txt
# 3                   7  45942  007_45942.txt
# 4                   7  45943  007_45943.txt
# ...               ...    ...            ...
# 6651              258  56386  258_56386.txt
# 6652              258  56387  258_56387.txt
# 6653              258  56388  258_56388.txt
# 6654              258  56389  258_56389.txt
# 6655              258  56390  258_56390.txt
#
#                                                    text
# 0     teacher: hi there <student>, all ok? student: ...
# 1     teacher: yeah i'm good thanks, just been for a...
# 2     teacher: yeah? what did you do? i'll come back...
# 3     teacher: ok i see ...too bad about the running...
# 4     teacher: yes i realise it's not easy really! i...
# ...                                                 ...
# ...

# %%
# for idx, row in all_texts.iterrows():
#     filename = row['d_id']
#     fp = os.path.join('/Users/mahathi/gispy2/GisPy/data/documents', filename)
#     with open(fp, 'w') as f:
#         f.writelines(row['text'])
